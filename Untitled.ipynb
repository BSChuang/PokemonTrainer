# %% [markdown]
# # Pokemon trainer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import ast
import math

# %%
# RUN TO CREATE CLEANED CSV FILES
""" pokedf = None
with open('pokemon-data.csv') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    pokemon = []
    colNames = []
    for row in reader:
        pokemon.append(' '.join(row).split(';'))
    colNames = pokemon[0]
    pokemon.pop(0)
    pokedf = pd.DataFrame(pokemon, columns=colNames)

pokedf.drop(['Tier', 'Next Evolution(s)'], axis=1, inplace=True)
pokedf.to_csv('pokemon-data-clean.csv', index=False) """

""" movedf = pd.read_csv('move-data.csv')
movedf.drop(['Index', 'Generation'], axis=1, inplace=True)
movedf.to_csv('move-data-clean.csv', index=False)
 """

# %% [markdown]
# ### Create Dataframes for pokemon dataset, move dataset and type dataset

# %%
def cleanup(arr):
    newArr = []
    for move in arr:
        newName = (move.replace('-', '')).replace("'", '') # Remove dashes
        if movedf[movedf['Name'] == newName]['Category'].values[0] == 'Status': # Remove status moves
            continue

        # Remove moves with no power or accuracy
        if np.isnan(movedf[movedf['Name'] == newName]['Power'].values[0]) or np.isnan(movedf[movedf['Name'] == newName]['Accuracy'].values[0]):
            continue
        
        newArr.append(newName) 
    return newArr 

def standardize(row):
    factor = 600 / (row['HP'] + row['Attack'] + row['Defense'] + row['Special Attack'] + row['Special Defense'] + row['Speed'])
    row['HP'] = math.floor(factor * row['HP'])
    row['Attack'] = math.floor(factor * row['Attack'])
    row['Defense'] = math.floor(factor * row['Defense'])
    row['Special Attack'] = math.floor(factor * row['Special Attack'])
    row['Special Defense'] = math.floor(factor * row['Special Defense'])
    row['Speed'] = math.floor(factor * row['Speed'])
    return row

movedf = pd.read_csv('move-data-clean.csv')
movedf['Name'] = movedf['Name'].apply(lambda x: (x.replace('-', '')).replace("'", '')) # Remove dashes (like in Double-Edge)
movedf['Power'] = movedf['Power'].apply(lambda x: int(x) if x != 'None' else None)
movedf['Accuracy'] = movedf['Accuracy'].apply(lambda x: int(x) if x != 'None' else None)

pokedf = pd.read_csv('pokemon-data-clean.csv')
for col in ['Types', 'Abilities', 'Moves']: # Turn the types, abilities, and moves from a string to a list
    pokedf[col] = pokedf[col].apply(ast.literal_eval)
pokedf = pokedf.apply(standardize, axis=1)
pokedf['Moves'] = pokedf['Moves'].apply(cleanup)

typedf = pd.read_csv('type-data-clean.csv', index_col=0)

allTypes = ['Normal', 'Fire', 'Water', 'Electric', 'Grass', 'Ice', 'Fighting', 'Poison', 'Ground', 'Flying', 'Psychic', 'Bug', 'Rock', 'Ghost', 'Dragon', 'Dark', 'Steel', 'Fairy']
allCategories = ['Physical', 'Special']

# %%
print(pokedf)

# %% [markdown]
# ## Experiment 1: Type Classifier
# ### Given the moves a pokemon will learn, can we predict its type?
# 1) Replace the moves with the move type, and count the number of moves in each type
#
# 2) Perform varying methods of supervised classification to find the optimal classifier and how quickly it will learn

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import RidgeClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

# %%
# Given abilties, predict type
def getMoveType(x): # Input: list of moves, Output: list of move types
    return movedf[movedf['Name'] == x]['Type'].values[0]

allVectorTypes = []
allVectorLabels = []
i = 0
for index in range(len(pokedf)):
    if i % 10 == 0:
        print(str(index) + "/" + str(len(pokedf)))
    pokeType = pokedf.loc[index, 'Types'][0]
    moves = pokedf.loc[index, 'Moves']
    moveTypes = list(map(getMoveType, moves))
    uniques, counts = np.unique(moveTypes, return_counts=True)
    vectorTypes = {type: 0 for type in allTypes}
    for i in range(len(uniques)):
        vectorTypes[uniques[i]] = counts[i]
    allVectorTypes.append(vectorTypes)
    allVectorLabels.append(allTypes.index(pokeType))
    i += 1

dVect = DictVectorizer()
dVectTypes = dVect.fit_transform(allVectorTypes).toarray()

# %%
def RidgeReg(X_train, X_test, y_train, y_test):
    rdg = RidgeClassifier()
    rdg.fit(X_train, y_train)
    return rdg.score(X_test, y_test)

def SVM(X_train, X_test, y_train, y_test):
    clf = svm.SVC()
    clf.fit(X_train, y_train)
    return clf.score(X_test, y_test)

def DecTree(X_train, X_test, y_train, y_test):
    dt = DecisionTreeClassifier(max_depth=10)
    dt.fit(X_train, y_train)
    return dt.score(X_test, y_test)

def GaussianBayes(X_train, X_test, y_train, y_test):
    gb = GaussianNB()
    gb.fit(X_train, y_train)
    return gb.score(X_test, y_test)

for key, classifier in {"Ridge": RidgeReg, "SVM": SVM, "Tree": DecTree, "GB": GaussianBayes}.items():
    x = []
    y = []
    for i in range(20, len(allVectorLabels), 20):
        X_train = dVectTypes[:i]
        X_test = dVectTypes[i:]

        y_train = allVectorLabels[:i]
        y_test = allVectorLabels[i:]

        x.append(i)
        y.append(classifier(X_train, X_test, y_train, y_test))
    plt.plot(x, y, label=key)

plt.title("Classifiers")
plt.legend()
plt.show()

# %% [markdown]
# ## Experiment 2: Simple pokemon battle (AKA advanced rock paper scissors)
# ### Create an agent to choose the best move given its move types and its opponent's type

# %%
from __future__ import absolute_import, division, print_function
import abc
import tensorflow as tf
import numpy as np
from sklearn.feature_extraction import DictVectorizer
import random
import math

from tf_agents.environments import py_environment
from tf_agents.environments import tf_environment
from tf_agents.environments import tf_py_environment
from tf_agents.environments import utils
from tf_agents.specs import array_spec
from tf_agents.environments import wrappers
from tf_agents.environments import suite_gym
from tf_agents.trajectories import time_step as ts

from tf_agents.agents.dqn import dqn_agent
from tf_agents.networks import q_network
from tf_agents.drivers import dynamic_step_driver
from tf_agents.environments import tf_py_environment
from tf_agents.environments import py_environment
#from tf_agents.environments import trajectory
from tf_agents.environments import wrappers
#from tf_agents.metrics import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.utils import common
from tf_agents.metrics import py_metrics
from tf_agents.metrics import tf_metrics
from tf_agents.drivers import py_driver
from tf_agents.drivers import dynamic_episode_driver

tf.compat.v1.enable_v2_behavior()

# %%
# Battle helper functions (Ignoring abilities and pp)
# Pokemon: [types, hp, attack, defense, special attack, special defense, speed, move1type, move1category, ..., move1accuracy, move2type, ..., move4accuracy]
# Moves: [type, category, pp, power, accuracy]
# one-hot encode: types, movetype, category 
""" 
print(movedf.loc[0].values)
print(typedf.loc['Water', 'Fire']) """
def calcDamage(poke1, poke2, move):
    move = poke1[24+23*move:24+23*(move+1)]
    attack = poke1[19] if move[18] == 'Physical' else poke1[21]
    defense = poke2[20] if move[18] == 'Physical' else poke2[22]
    modifier = 2
    types = onehotToType(poke2[:18])
    for type in types:
        modifier *= typedf.loc[onehotToType(move[:18]), type]
    damage = ((2/5 + 2) * move[20] * attack / defense / 50 + 2) * modifier# * (move[21] > np.random.randint(1, 101))
    return math.ceil(damage)

def typeToOneHot(types): # Input: list of types, output: one hot array where types are 1, else 0
    onehot = [0] * len(allTypes)
    for type in types:
        onehot[allTypes.index(type)] = 1
    
    return onehot

def onehotToType(onehot): # Input onehot of types, output: list of types
    onehot = np.array(onehot)
    types = np.array(allTypes)
    return types[np.where(onehot == 1)]

def randPokemon():
    poke = pokedf[:20].sample(1).values[0]
    poke = np.delete(poke, 2) # Remove abilties
    poke[8] = random.sample(poke[8], 4) # Choose 4 random moves for the pokemon
    return poke


def moveToVector(move): # Input: move name, output: move vector (movetype (one-hot), move category (one-hot), pp, power, accuracy)
    move = movedf[movedf['Name'] == move]
    moveType = typeToOneHot([move['Type'].values[0]])
    moveCategory = [1, 0] if move['Category'].values[0] == 'Physical' else [0, 1]
    moveOthers = [move['PP'].values[0], move['Power'].values[0], move['Accuracy'].values[0]]
    return np.concatenate((moveType, moveCategory, moveOthers))


def pokeToVector(poke):
    pokeVec = np.concatenate((typeToOneHot(poke[1]), poke[2:8]))

    for move in poke[8]:
        pokeVec = np.concatenate((pokeVec, moveToVector(move)))
    
    return pokeVec.astype(np.int32)

# %%
class PokemonEnv(py_environment.PyEnvironment):
  def __init__(self):
    self.round = 0
    self._action_spec = array_spec.BoundedArraySpec(
        shape=(), dtype=np.int32, minimum=0, maximum=3, name='action') # Action is single int from 0-3 signifying chosen move
    self._observation_spec = array_spec.BoundedArraySpec( # Observation: [poke2type (18), poke1move1type (18), poke1move2type (18), poke1move3type (18), poke1move4type (18)]
        shape=(90,), dtype=np.int32, name='observation')
    
    self.poke1 = randPokemon()
    self.poke2 = randPokemon()

    self.poke1Vec = pokeToVector(self.poke1)
    self.poke2Vec = pokeToVector(self.poke2)

    moves = []
    for move in self.poke1[8]:
        moves = np.concatenate((moves, moveToVector(move)[:18]))

    self._state = np.concatenate((self.poke2Vec[:18], moves)).astype(np.int32) # State: poke1, poke2[type and stats]
    self._episode_ended = False

  def action_spec(self):
    return self._action_spec

  def observation_spec(self):
    return self._observation_spec

  def _reset(self):
    self.round = 0
    self.poke1 = randPokemon()
    self.poke2 = randPokemon()

    self.poke1Vec = pokeToVector(self.poke1)
    self.poke2Vec = pokeToVector(self.poke2)

    moves = []
    for move in self.poke1[8]:
        moves = np.concatenate((moves, moveToVector(move)[:18]))

    self._state = np.concatenate((self.poke2Vec[:18], moves)).astype(np.int32) # State: poke1, poke2[type and stats]
    self._episode_ended = False
    return ts.restart(self._state)

  def _step(self, action):
    if self._episode_ended:
      return self.reset()

    if action == 0 or action == 1 or action == 2 or action == 3: # If action is valid
        pokeTypes = onehotToType(self._state[:18])
        moveType = onehotToType(self._state[18 + 18*action: 18 + 18 * (action + 1)])[0]
        reward = 100
        for pokeType in pokeTypes:
          reward *= typedf.loc[moveType, pokeType]
      
    self._episode_ended = True
    if self._episode_ended:
      return ts.termination(self._state, reward)
    else:
      return ts.transition(self._state, reward=reward, discount=1)

# %%
env = PokemonEnv()
utils.validate_py_environment(env, episodes=5)

# %% [markdown]
# ## Experiment 2: Pokemon Battle
# ### Create two agents to pokemon battle and ultimately become the region's best pokemon champions
# 1) Create a (simplified) environment where trainers may battle one another
#
# 2) Use tensorflow/tf-agents to create agent
#
# 3) Train the agent against random, then against algorithm, then itself possibly
#
# 4) Result: agent who perform the best given its pokemon and abilities. Pokemon can be swapped out
#
# 5) Constraints: no status effects (dataset does not have the effects of status effects). No items
#
# 5) Stretch goals: agents take turns picking 6 pokemon to battle each other, then pick the pokemon's abilities

# %%
from __future__ import absolute_import, division, print_function
import abc
import tensorflow as tf
import numpy as np
from sklearn.feature_extraction import DictVectorizer
import random
import math

from tf_agents.agents.dqn import dqn_agent
from tf_agents.networks import q_network
from tf_agents.drivers import dynamic_step_driver
from tf_agents.environments import tf_py_environment
#from tf_agents.environments import trajectory
from tf_agents.environments import wrappers
#from tf_agents.metrics import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.policies import random_tf_policy
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.utils import common
from tf_agents.metrics import py_metrics
from tf_agents.metrics import tf_metrics
from tf_agents.drivers import py_driver
from tf_agents.drivers import dynamic_episode_driver

tf.compat.v1.enable_v2_behavior()

# %% [markdown]
# ### Creating the environment
# https://www.tensorflow.org/agents/tutorials/2_environments_tutorial
#
# https://towardsdatascience.com/tf-agents-tutorial-a63399218309

# %%
# Battle helper functions (Ignoring abilities and pp)
# Pokemon: [types, hp, attack, defense, special attack, special defense, speed, move1type, move1category, ..., move1accuracy, move2type, ..., move4accuracy]
# Moves: [type, category, pp, power, accuracy]
# one-hot encode: types, movetype, category 
""" 
print(movedf.loc[0].values)
print(typedf.loc['Water', 'Fire']) """
def calcDamage(poke1, poke2, move):
    move = poke1[24+23*move:24+23*(move+1)]
    attack = poke1[19] if move[18] == 'Physical' else poke1[21]
    defense = poke2[20] if move[18] == 'Physical' else poke2[22]
    modifier = 2
    types = onehotToType(poke2[:18])
    for type in types:
        modifier *= typedf.loc[onehotToType(move[:18]), type]
    damage = ((2/5 + 2) * move[20] * attack / defense / 50 + 2) * modifier# * (move[21] > np.random.randint(1, 101))
    return math.ceil(damage)

def typeToOneHot(types): # Input: list of types, output: one hot array where types are 1, else 0
    onehot = [0] * len(allTypes)
    for type in types:
        onehot[allTypes.index(type)] = 1
    
    return onehot

def onehotToType(onehot): # Input onehot of types, output: list of types
    onehot = np.array(onehot)
    types = np.array(allTypes)
    return types[np.where(onehot == 1)]

def randPokemon():
    poke = pokedf[:20].sample(1).values[0]
    poke = np.delete(poke, 2) # Remove abilties
    poke[8] = random.sample(poke[8], 4) # Choose 4 random moves for the pokemon
    return poke


def moveToVector(move): # Input: move name, output: move vector (movetype (one-hot), move category (one-hot), pp, power, accuracy)
    move = movedf[movedf['Name'] == move]
    moveType = typeToOneHot([move['Type'].values[0]])
    moveCategory = [1, 0] if move['Category'].values[0] == 'Physical' else [0, 1]
    moveOthers = [move['PP'].values[0], move['Power'].values[0], move['Accuracy'].values[0]]
    return np.concatenate((moveType, moveCategory, moveOthers))


def pokeToVector(poke):
    pokeVec = np.concatenate((typeToOneHot(poke[1]), poke[2:8]))

    for move in poke[8]:
        pokeVec = np.concatenate((pokeVec, moveToVector(move)))
    
    return pokeVec.astype(np.int32)

# %%
#poke1 = np.array(['Abomasnow', ['Grass', 'Ice'], 90, 92, 75, 92, 85, 60, ['Ice Punch', 'Powder Snow', 'Rock Slide', 'Razor Leaf']])
class PokemonEnv(py_environment.PyEnvironment):
  def __init__(self):
    self._action_spec = array_spec.BoundedArraySpec(
        shape=(), dtype=np.int32, minimum=0, maximum=3, name='action') # Action is single int from 0-3 signifying chosen move
    self._observation_spec = array_spec.BoundedArraySpec( # Observation: [poke1, poke2[type and stats]] OR [poke1type, poke2type, poke1move1type, poke1move2type, poke1move3type, poke1move4type]
        shape=(140,), dtype=np.int32, name='observation')
    
    self.poke1 = randPokemon()
    self.poke2 = randPokemon()

    self.poke1Vec = pokeToVector(self.poke1)
    self.poke2Vec = pokeToVector(self.poke2)
    self._state = np.concatenate((self.poke1Vec, self.poke2Vec[:24])) # State: poke1, poke2[type and stats]
    self._episode_ended = False

  def action_spec(self):
    return self._action_spec

  def observation_spec(self):
    return self._observation_spec

  def _reset(self):
    self.poke1 = randPokemon()
    self.poke2 = randPokemon()

    self.poke1Vec = pokeToVector(self.poke1)
    self.poke2Vec = pokeToVector(self.poke2)

    self._state = np.concatenate((self.poke1Vec, self.poke2Vec[:24]))
    self._episode_ended = False
    return ts.restart(self._state)

  def _step(self, action):
    if self._episode_ended:
      # The last action ended the episode. Ignore the current action and start
      # a new episode.
      return self.reset()

    poke2StartHP = self.poke2Vec[18]
    self.poke2Action = random.randint(0, 3)

    # Make sure episodes don't go on forever.
    if self._state[18] == 0 or self._state[134] == 0: # If either have fainted, end episode
      self._episode_ended = True
    else:
      if action == 0 or action == 1 or action == 2 or action == 3: # If action is valid
        if self.poke1Vec[23] > self.poke2Vec[23]:
          order = {'first': self.poke1Vec, 'second': self.poke2Vec, 'firstAction': action, 'secondAction': self.poke2Action}
        else:
          order = {'first': self.poke2Vec, 'second': self.poke1Vec, 'firstAction': self.poke2Action, 'secondAction': action}

        firstDamage = calcDamage(order['first'], order['second'], order['firstAction']) # Get damage
        order['second'][18] = max(order['second'][18] - firstDamage, 0) # Apply damage
        if order['second'][18] > 0: # If poke2 is still alive
          secondDamage = calcDamage(order['second'], order['first'], order['secondAction']) # Get damage
          order['first'][18] = max(order['first'][18] - secondDamage, 0) # Apply damage
          if order['first'][18] == 0: # If poke1 fainted end episode
            self._episode_ended = True
        else:
          self._episode_ended = True

    # If neither have fainted, remove 1 pp from each pokemon's move
    self.poke1Vec[24+(23*action)+20] -= 1
    self.poke1Vec[24+(23*self.poke2Action)+20] -= 1

    self._state = np.concatenate((self.poke1Vec, self.poke2Vec[:24]))
    poke2HPDiff = poke2StartHP - self.poke2Vec[18]
    if self._episode_ended:
      if self.poke1Vec[18] > 0 and self.poke2Vec[18] == 0:
        reward = 50
      elif self.poke1Vec[18] == 0 and self.poke2Vec[18] > 0:
        reward = -50
      else:
        reward = 0
      reward += poke2HPDiff # Extra reward based on damage dealt
      return ts.termination(self._state, reward)
    else:
      return ts.transition(self._state, reward=poke2HPDiff, discount=0.999)

# %%
env = PokemonEnv()
utils.validate_py_environment(env, episodes=5)

poke1Prev, poke2Prev = env.poke1Vec[18], env.poke2Vec[18]
env._step(0)
poke1Next, poke2Next = env.poke1Vec[18], env.poke2Vec[18]
print(env.poke1[0], "used", env.poke1[8][0], "|", poke2Prev, "->", poke2Next)
print(env.poke2[0], "used", env.poke2[8][env.poke2Action], "|", poke1Prev, "->", poke1Next)

# %% [markdown]
# ## Run classifier

# %%
train_py_env = wrappers.TimeLimit(PokemonEnv(), duration=100)
eval_py_env = wrappers.TimeLimit(PokemonEnv(), duration=100)

train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# %%
def compute_avg_return(environment, policy, num_episodes=10):

    total_return = 0.0
    for _ in range(num_episodes):

        time_step = environment.reset()
        episode_return = 0.0

        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
            total_return += episode_return

    avg_return = total_return / num_episodes
    return avg_return.numpy()[0]

num_iterations = 75000  # @param

initial_collect_steps = 1000  # @param
collect_steps_per_iteration = 1  # @param
replay_buffer_capacity = 100000  # @param

fc_layer_params = (100,)

batch_size = 128  # @param
learning_rate = 1e-5  # @param
log_interval = 200  # @param

num_eval_episodes = 2  # @param
eval_interval = 1000  # @param

q_net = q_network.QNetwork(
        train_env.observation_spec(),
        train_env.action_spec(),
        fc_layer_params=fc_layer_params)

optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate)

train_step_counter = tf.compat.v2.Variable(0)

tf_agent = dqn_agent.DqnAgent(
        train_env.time_step_spec(),
        train_env.action_spec(),
        q_network=q_net,
        optimizer=optimizer,
        #td_errors_loss_fn = dqn_agent.element_wise_squared_loss,
        train_step_counter=train_step_counter)

tf_agent.initialize()

eval_policy = tf_agent.policy
collect_policy = tf_agent.collect_policy

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
        data_spec=tf_agent.collect_data_spec,
        batch_size=train_env.batch_size,
        max_length=replay_buffer_capacity)

replay_observer = [replay_buffer.add_batch]

dataset = replay_buffer.as_dataset(
            num_parallel_calls=3,
            sample_batch_size=batch_size,
    num_steps=2).prefetch(3)
    
iterator = iter(dataset)

train_metrics = [
            tf_metrics.NumberOfEpisodes(),
            tf_metrics.EnvironmentSteps(),
            tf_metrics.AverageReturnMetric(),
            tf_metrics.AverageEpisodeLengthMetric(),
]

driver = dynamic_step_driver.DynamicStepDriver(
            train_env,
            collect_policy,
            observers=replay_observer + train_metrics,
    num_steps=1)
# Out:
# WARNING:tensorflow:From C:\Users\ben\AppData\Local\Programs\Python\Python37\lib\site-packages\tensorflow\python\autograph\operators\control_flow.py:1004: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %%
episode_len = []

final_time_step, policy_state = driver.run()

for i in range(num_iterations):
    final_time_step, _ = driver.run(final_time_step, policy_state)

    experience, _ = next(iterator)
    train_loss = tf_agent.train(experience=experience)
    step = tf_agent.train_step_counter.numpy()

    if step % log_interval == 0:
        print('step = {0}: loss = {1}'.format(step, train_loss.loss))
        episode_len.append(train_metrics[3].result().numpy())
        print('Average episode length: {}'.format(train_metrics[3].result().numpy()))

    if step % eval_interval == 0:
        avg_return = compute_avg_return(eval_env, tf_agent.policy, num_eval_episodes)
        print('step = {0}: Average Return = {1}'.format(step, avg_return))
plt.plot(episode_len)
plt.show()
# Out:
# .121273040771484
# Average episode length: 1.0
# step = 22000: loss = 31.538196563720703
# Average episode length: 1.0
# step = 22000: Average Return = 75.0
# step = 22200: loss = 37.358638763427734
# Average episode length: 1.0
# step = 22400: loss = 37.78557586669922
# Average episode length: 1.0
# step = 22600: loss = 27.911922454833984
# Average episode length: 1.0
# step = 22800: loss = 28.02001190185547
# Average episode length: 1.0
# step = 23000: loss = 32.93533706665039
# Average episode length: 1.0
# step = 23000: Average Return = 50.0
# step = 23200: loss = 32.95341873168945
# Average episode length: 1.0
# step = 23400: loss = 26.661251068115234
# Average episode length: 1.0
# step = 23600: loss = 31.998641967773438
# Average episode length: 1.0
# step = 23800: loss = 37.24723434448242
# Average episode length: 1.0
# step = 24000: loss = 35.17982482910156
# Average episode length: 1.0
# step = 24000: Average Return = 75.0
# step = 24200: loss = 35.81629943847656
# Average episode length: 1.0
# step = 24400: loss = 41.7684440612793
# Average episode length: 1.0
# step = 24600: loss = 29.016281127929688
# Average episode length: 1.0
# step = 24800: loss = 26.717344284057617
# Average episode length: 1.0
# step = 25000: loss = 23.453079223632812
# Average episode length: 1.0
# step = 25000: Average Return = 0.0
# step = 25200: loss = 35.126461029052734
# Average episode length: 1.0
# step = 25400: loss = 34.06966781616211
# Average episode length: 1.0
# step = 25600: loss = 31.126651763916016
# Average episode length: 1.0
# step = 25800: loss = 32.70947265625
# Average episode length: 1.0
# step = 26000: loss = 30.765674591064453
# Average episode length: 1.0
# step = 26000: Average Return = 50.0
# step = 26200: loss = 33.813167572021484
# Average episode length: 1.0
# step = 26400: loss = 29.022891998291016
# Average episode length: 1.0
# step = 26600: loss = 28.95085906982422
# Average episode length: 1.0
# step = 26800: loss = 40.34245300292969
# Average episode length: 1.0
# step = 27000: loss = 37.20943832397461
# Average episode length: 1.0
# step = 27000: Average Return = 100.0
# step = 27200: loss = 23.55472183227539
# Average episode length: 1.0
# step = 27400: loss = 25.433406829833984
# Average episode length: 1.0
# step = 27600: loss = 26.15188980102539
# Average episode length: 1.0
# step = 27800: loss = 37.11080551147461
# Average episode length: 1.0
# step = 28000: loss = 32.62726593017578
# Average episode length: 1.0
# step = 28000: Average Return = 50.0
# step = 28200: loss = 24.19687843322754
# Average episode length: 1.0
# step = 28400: loss = 30.466232299804688
# Average episode length: 1.0
# step = 28600: loss = 29.012643814086914
# Average episode length: 1.0
# step = 28800: loss = 34.055763244628906
# Average episode length: 1.0
# step = 29000: loss = 25.16387939453125
# Average episode length: 1.0
# step = 29000: Average Return = 75.0
# step = 29200: loss = 27.11170196533203
# Average episode length: 1.0
# step = 29400: loss = 39.54029083251953
# Average episode length: 1.0
# step = 29600: loss = 21.88629150390625
# Average episode length: 1.0
# step = 29800: loss = 30.99791717529297
# Average episode length: 1.0
# step = 30000: loss = 27.899410247802734
# Average episode length: 1.0
# step = 30000: Average Return = 50.0
# step = 30200: loss = 22.327713012695312
# Average episode length: 1.0
# step = 30400: loss = 31.073223114013672
# Average episode length: 1.0
# step = 30600: loss = 21.696258544921875
# Average episode length: 1.0
# step = 30800: loss = 28.393421173095703
# Average episode length: 1.0
# step = 31000: loss = 27.453853607177734
# Average episode length: 1.0
# step = 31000: Average Return = 100.0
# step = 31200: loss = 30.559391021728516
# Average episode length: 1.0
# step = 31400: loss = 32.48295593261719
# Average episode length: 1.0
# step = 31600: loss = 26.744953155517578
# Average episode length: 1.0
# step = 31800: loss = 28.80394744873047
# Average episode length: 1.0
# step = 32000: loss = 27.77859115600586
# Average episode length: 1.0
# step = 32000: Average Return = 75.0
# step = 32200: loss = 22.938854217529297
# Average episode length: 1.0
# step = 32400: loss = 19.69873809814453
# Average episode length: 1.0
# step = 32600: loss = 26.07436752319336
# Average episode length: 1.0
# step = 32800: loss = 27.92676544189453
# Average episode length: 1.0
# step = 33000: loss = 21.670875549316406
# Average episode length: 1.0
# step = 33000: Average Return = 75.0
# step = 33200: loss = 23.956035614013672
# Average episode length: 1.0
# step = 33400: loss = 29.2169246673584
# Average episode length: 1.0
# step = 33600: loss = 28.574085235595703
# Average episode length: 1.0
# step = 33800: loss = 23.48819351196289
# Average episode length: 1.0
# step = 34000: loss = 21.05457305908203
# Average episode length: 1.0
# step = 34000: Average Return = 25.0
# step = 34200: loss = 30.692310333251953
# Average episode length: 1.0
# step = 34400: loss = 21.553070068359375
# Average episode length: 1.0
# step = 34600: loss = 21.870121002197266
# Average episode length: 1.0
# step = 34800: loss = 30.140077590942383
# Average episode length: 1.0
# step = 35000: loss = 23.855432510375977
# Average episode length: 1.0
# step = 35000: Average Return = 100.0
# step = 35200: loss = 24.64199447631836
# Average episode length: 1.0
# step = 35400: loss = 27.256481170654297
# Average episode length: 1.0
# step = 35600: loss = 22.761791229248047
# Average episode length: 1.0
# step = 35800: loss = 21.475486755371094
# Average episode length: 1.0
# step = 36000: loss = 25.719778060913086
# Average episode length: 1.0
# step = 36000: Average Return = 150.0
# step = 36200: loss = 31.26063346862793
# Average episode length: 1.0
# step = 36400: loss = 22.771238327026367
# Average episode length: 1.0
# step = 36600: loss = 23.495718002319336
# Average episode length: 1.0
# step = 36800: loss = 22.731231689453125
# Average episode length: 1.0
# step = 37000: loss = 19.68959617614746
# Average episode length: 1.0
# step = 37000: Average Return = 100.0
# step = 37200: loss = 22.76202392578125
# Average episode length: 1.0
# step = 37400: loss = 15.597160339355469
# Average episode length: 1.0
# step = 37600: loss = 18.095245361328125
# Average episode length: 1.0
# step = 37800: loss = 24.354663848876953
# Average episode length: 1.0
# step = 38000: loss = 23.03321075439453
# Average episode length: 1.0
# step = 38000: Average Return = 100.0
# step = 38200: loss = 24.634862899780273
# Average episode length: 1.0
# step = 38400: loss = 17.531455993652344
# Average episode length: 1.0
# step = 38600: loss = 21.491464614868164
# Average episode length: 1.0
# step = 38800: loss = 18.169124603271484
# Average episode length: 1.0
# step = 39000: loss = 26.187564849853516
# Average episode length: 1.0
# step = 39000: Average Return = 75.0
# step = 39200: loss = 19.811222076416016
# Average episode length: 1.0
# step = 39400: loss = 23.309526443481445
# Average episode length: 1.0
# step = 39600: loss = 20.30356788635254
# Average episode length: 1.0
# step = 39800: loss = 19.593610763549805
# Average episode length: 1.0
# step = 40000: loss = 18.988147735595703
# Average episode length: 1.0
# step = 40000: Average Return = 150.0
# step = 40200: loss = 22.32611656188965
# Average episode length: 1.0
# step = 40400: loss = 22.354459762573242
# Average episode length: 1.0
# step = 40600: loss = 17.06817054748535
# Average episode length: 1.0
# step = 40800: loss = 16.357364654541016
# Average episode length: 1.0
# step = 41000: loss = 16.890987396240234
# Average episode length: 1.0
# step = 41000: Average Return = 75.0
# step = 41200: loss = 22.01798439025879
# Average episode length: 1.0
# step = 41400: loss = 15.292168617248535
# Average episode length: 1.0
# step = 41600: loss = 25.942005157470703
# Average episode length: 1.0
# step = 41800: loss = 21.804122924804688
# Average episode length: 1.0
# step = 42000: loss = 31.232120513916016
# Average episode length: 1.0
# step = 42000: Average Return = 37.5
# step = 42200: loss = 17.421545028686523
# Average episode length: 1.0
# step = 42400: loss = 18.4368953704834
# Average episode length: 1.0
# step = 42600: loss = 13.630074501037598
# Average episode length: 1.0
# step = 42800: loss = 20.08378028869629
# Average episode length: 1.0
# step = 43000: loss = 18.838714599609375
# Average episode length: 1.0
# step = 43000: Average Return = 100.0
# step = 43200: loss = 16.901172637939453
# Average episode length: 1.0
# step = 43400: loss = 27.185617446899414
# Average episode length: 1.0
# step = 43600: loss = 21.427608489990234
# Average episode length: 1.0
# step = 43800: loss = 15.1407470703125
# Average episode length: 1.0
# step = 44000: loss = 24.10381317138672
# Average episode length: 1.0
# step = 44000: Average Return = 100.0
# step = 44200: loss = 21.229707717895508
# Average episode length: 1.0
# step = 44400: loss = 19.546737670898438
# Average episode length: 1.0
# step = 44600: loss = 25.163419723510742
# Average episode length: 1.0
# step = 44800: loss = 19.76310157775879
# Average episode length: 1.0
# step = 45000: loss = 19.606176376342773
# Average episode length: 1.0
# step = 45000: Average Return = 150.0
# step = 45200: loss = 23.40304183959961
# Average episode length: 1.0
# step = 45400: loss = 24.587276458740234
# Average episode length: 1.0
# step = 45600: loss = 18.286231994628906
# Average episode length: 1.0
# step = 45800: loss = 19.06664276123047
# Average episode length: 1.0
# step = 46000: loss = 19.667072296142578
# Average episode length: 1.0
# step = 46000: Average Return = 100.0
# step = 46200: loss = 18.906959533691406
# Average episode length: 1.0
# step = 46400: loss = 15.727697372436523
# Average episode length: 1.0
# step = 46600: loss = 18.226749420166016
# Average episode length: 1.0
# step = 46800: loss = 19.89090919494629
# Average episode length: 1.0
# step = 47000: loss = 21.91272735595703
# Average episode length: 1.0
# step = 47000: Average Return = 150.0
# step = 47200: loss = 13.156416893005371
# Average episode length: 1.0
# step = 47400: loss = 24.98949432373047
# Average episode length: 1.0
# step = 47600: loss = 17.20313262939453
# Average episode length: 1.0
# step = 47800: loss = 19.48983383178711
# Average episode length: 1.0
# step = 48000: loss = 24.772136688232422
# Average episode length: 1.0
# step = 48000: Average Return = 50.0
# step = 48200: loss = 18.182340621948242
# Average episode length: 1.0
# step = 48400: loss = 17.793346405029297
# Average episode length: 1.0
# step = 48600: loss = 18.121109008789062
# Average episode length: 1.0
# step = 48800: loss = 23.443737030029297
# Average episode length: 1.0
# step = 49000: loss = 19.152469635009766
# Average episode length: 1.0
# step = 49000: Average Return = 50.0
# step = 49200: loss = 16.009628295898438
# Average episode length: 1.0
# step = 49400: loss = 15.079557418823242
# Average episode length: 1.0
# step = 49600: loss = 17.85157585144043
# Average episode length: 1.0
# step = 49800: loss = 12.905077934265137
# Average episode length: 1.0
# step = 50000: loss = 23.052738189697266
# Average episode length: 1.0
# step = 50000: Average Return = 100.0
# step = 50200: loss = 19.97163963317871
# Average episode length: 1.0
# step = 50400: loss = 17.377750396728516
# Average episode length: 1.0
# step = 50600: loss = 14.825590133666992
# Average episode length: 1.0
# step = 50800: loss = 16.7083740234375
# Average episode length: 1.0
# step = 51000: loss = 20.094919204711914
# Average episode length: 1.0
# step = 51000: Average Return = 37.5
# step = 51200: loss = 11.118406295776367
# Average episode length: 1.0
# step = 51400: loss = 17.628509521484375
# Average episode length: 1.0
# step = 51600: loss = 22.904972076416016
# Average episode length: 1.0
# step = 51800: loss = 17.76765251159668
# Average episode length: 1.0
# step = 52000: loss = 19.660350799560547
# Average episode length: 1.0
# step = 52000: Average Return = 125.0
# step = 52200: loss = 15.879480361938477
# Average episode length: 1.0
# step = 52400: loss = 13.990923881530762
# Average episode length: 1.0
# step = 52600: loss = 16.57608985900879
# Average episode length: 1.0
# step = 52800: loss = 22.328205108642578
# Average episode length: 1.0
# step = 53000: loss = 19.487102508544922
# Average episode length: 1.0
# step = 53000: Average Return = 50.0
# step = 53200: loss = 18.183828353881836
# Average episode length: 1.0
# step = 53400: loss = 19.855064392089844
# Average episode length: 1.0
# step = 53600: loss = 15.306557655334473
# Average episode length: 1.0
# step = 53800: loss = 17.40167808532715
# Average episode length: 1.0
# step = 54000: loss = 18.21714210510254
# Average episode length: 1.0
# step = 54000: Average Return = 150.0
# step = 54200: loss = 20.46268081665039
# Average episode length: 1.0
# step = 54400: loss = 18.78734588623047
# Average episode length: 1.0
# step = 54600: loss = 19.314794540405273
# Average episode length: 1.0
# step = 54800: loss = 19.578887939453125
# Average episode length: 1.0
# step = 55000: loss = 20.453937530517578
# Average episode length: 1.0
# step = 55000: Average Return = 50.0
# step = 55200: loss = 21.33671760559082
# Average episode length: 1.0
# step = 55400: loss = 11.884580612182617
# Average episode length: 1.0
# step = 55600: loss = 21.39166831970215
# Average episode length: 1.0
# step = 55800: loss = 17.09205436706543
# Average episode length: 1.0
# step = 56000: loss = 13.940760612487793
# Average episode length: 1.0
# step = 56000: Average Return = 150.0
# step = 56200: loss = 20.61634063720703
# Average episode length: 1.0
# step = 56400: loss = 19.17416763305664
# Average episode length: 1.0
# step = 56600: loss = 16.59864616394043
# Average episode length: 1.0
# step = 56800: loss = 21.537540435791016
# Average episode length: 1.0
# step = 57000: loss = 15.374267578125
# Average episode length: 1.0
# step = 57000: Average Return = 100.0
# step = 57200: loss = 18.871368408203125
# Average episode length: 1.0
# step = 57400: loss = 17.334430694580078
# Average episode length: 1.0
# step = 57600: loss = 13.216228485107422
# Average episode length: 1.0
# step = 57800: loss = 19.61739158630371
# Average episode length: 1.0
# step = 58000: loss = 20.863788604736328
# Average episode length: 1.0
# step = 58000: Average Return = 50.0
# step = 58200: loss = 18.192447662353516
# Average episode length: 1.0
# step = 58400: loss = 17.575401306152344
# Average episode length: 1.0
# step = 58600: loss = 19.08324432373047
# Average episode length: 1.0
# step = 58800: loss = 19.532135009765625
# Average episode length: 1.0
# step = 59000: loss = 22.016632080078125
# Average episode length: 1.0
# step = 59000: Average Return = 100.0
# step = 59200: loss = 18.22325325012207
# Average episode length: 1.0
# step = 59400: loss = 19.235885620117188
# Average episode length: 1.0
# step = 59600: loss = 18.837976455688477
# Average episode length: 1.0
# step = 59800: loss = 20.482051849365234
# Average episode length: 1.0
# step = 60000: loss = 25.95254898071289
# Average episode length: 1.0
# step = 60000: Average Return = 50.0
# step = 60200: loss = 21.63486671447754
# Average episode length: 1.0
# step = 60400: loss = 17.196949005126953
# Average episode length: 1.0
# step = 60600: loss = 10.209053039550781
# Average episode length: 1.0
# step = 60800: loss = 17.85192108154297
# Average episode length: 1.0
# step = 61000: loss = 15.6610107421875
# Average episode length: 1.0
# step = 61000: Average Return = 100.0
# step = 61200: loss = 18.67593765258789
# Average episode length: 1.0
# step = 61400: loss = 18.582897186279297
# Average episode length: 1.0
# step = 61600: loss = 25.07965850830078
# Average episode length: 1.0
# step = 61800: loss = 16.388822555541992
# Average episode length: 1.0
# step = 62000: loss = 18.404766082763672
# Average episode length: 1.0
# step = 62000: Average Return = 50.0
# step = 62200: loss = 21.953022003173828
# Average episode length: 1.0
# step = 62400: loss = 16.301162719726562
# Average episode length: 1.0
# step = 62600: loss = 26.864543914794922
# Average episode length: 1.0
# step = 62800: loss = 23.336008071899414
# Average episode length: 1.0
# step = 63000: loss = 18.814485549926758
# Average episode length: 1.0
# step = 63000: Average Return = 100.0
# step = 63200: loss = 11.981467247009277
# Average episode length: 1.0
# step = 63400: loss = 14.615156173706055
# Average episode length: 1.0
# step = 63600: loss = 20.79686164855957
# Average episode length: 1.0
# step = 63800: loss = 12.829187393188477
# Average episode length: 1.0
# step = 64000: loss = 16.216720581054688
# Average episode length: 1.0
# step = 64000: Average Return = 125.0
# step = 64200: loss = 16.441120147705078
# Average episode length: 1.0
# step = 64400: loss = 16.417713165283203
# Average episode length: 1.0
# step = 64600: loss = 21.33970069885254
# Average episode length: 1.0
# step = 64800: loss = 15.18753719329834
# Average episode length: 1.0
# step = 65000: loss = 17.15880584716797
# Average episode length: 1.0
# step = 65000: Average Return = 100.0
# step = 65200: loss = 16.708940505981445
# Average episode length: 1.0
# step = 65400: loss = 14.792327880859375
# Average episode length: 1.0
# step = 65600: loss = 13.855676651000977
# Average episode length: 1.0
# step = 65800: loss = 16.049158096313477
# Average episode length: 1.0
# step = 66000: loss = 15.994394302368164
# Average episode length: 1.0
# step = 66000: Average Return = 250.0
# step = 66200: loss = 22.40083122253418
# Average episode length: 1.0
# step = 66400: loss = 26.718273162841797
# Average episode length: 1.0
# step = 66600: loss = 16.104511260986328
# Average episode length: 1.0
# step = 66800: loss = 22.878040313720703
# Average episode length: 1.0
# step = 67000: loss = 19.78789520263672
# Average episode length: 1.0
# step = 67000: Average Return = 25.0
# step = 67200: loss = 15.063138961791992
# Average episode length: 1.0
# step = 67400: loss = 19.87973403930664
# Average episode length: 1.0
# step = 67600: loss = 16.021629333496094
# Average episode length: 1.0
# step = 67800: loss = 13.414791107177734
# Average episode length: 1.0
# step = 68000: loss = 16.870630264282227
# Average episode length: 1.0
# step = 68000: Average Return = 100.0
# step = 68200: loss = 13.372304916381836
# Average episode length: 1.0
# step = 68400: loss = 15.121252059936523
# Average episode length: 1.0
# step = 68600: loss = 15.630376815795898
# Average episode length: 1.0
# step = 68800: loss = 20.57356071472168
# Average episode length: 1.0
# step = 69000: loss = 19.074356079101562
# Average episode length: 1.0
# step = 69000: Average Return = 100.0
# step = 69200: loss = 23.610286712646484
# Average episode length: 1.0
# step = 69400: loss = 16.430667877197266
# Average episode length: 1.0
# step = 69600: loss = 13.41812515258789
# Average episode length: 1.0
# step = 69800: loss = 28.82575225830078
# Average episode length: 1.0
# step = 70000: loss = 14.603706359863281
# Average episode length: 1.0
# step = 70000: Average Return = 50.0
# step = 70200: loss = 15.057387351989746
# Average episode length: 1.0
# step = 70400: loss = 19.724185943603516
# Average episode length: 1.0
# step = 70600: loss = 16.292394638061523
# Average episode length: 1.0
# step = 70800: loss = 16.307838439941406
# Average episode length: 1.0
# step = 71000: loss = 16.357349395751953
# Average episode length: 1.0
# step = 71000: Average Return = 100.0
# step = 71200: loss = 12.073007583618164
# Average episode length: 1.0
# step = 71400: loss = 17.654376983642578
# Average episode length: 1.0
# step = 71600: loss = 17.78118896484375
# Average episode length: 1.0
# step = 71800: loss = 18.6383113861084
# Average episode length: 1.0
# step = 72000: loss = 23.812156677246094
# Average episode length: 1.0
# step = 72000: Average Return = 100.0
# step = 72200: loss = 16.113069534301758
# Average episode length: 1.0
# step = 72400: loss = 15.393829345703125
# Average episode length: 1.0
# step = 72600: loss = 21.925907135009766
# Average episode length: 1.0
# step = 72800: loss = 22.455060958862305
# Average episode length: 1.0
# step = 73000: loss = 18.450157165527344
# Average episode length: 1.0
# step = 73000: Average Return = 50.0
# step = 73200: loss = 14.068333625793457
# Average episode length: 1.0
# step = 73400: loss = 15.513738632202148
# Average episode length: 1.0
# step = 73600: loss = 16.06708526611328
# Average episode length: 1.0
# step = 73800: loss = 13.938300132751465
# Average episode length: 1.0
# step = 74000: loss = 18.31512451171875
# Average episode length: 1.0
# step = 74000: Average Return = 50.0
# step = 74200: loss = 25.443559646606445
# Average episode length: 1.0
# step = 74400: loss = 16.505538940429688
# Average episode length: 1.0
# step = 74600: loss = 18.444576263427734
# Average episode length: 1.0
# step = 74800: loss = 20.707908630371094
# Average episode length: 1.0
# step = 75000: loss = 21.415504455566406
# Average episode length: 1.0
# step = 75000: Average Return = 100.0
